# %%
import pandas as pd
import numpy as np
import json

# %%
NY_data_df = pd.read_csv("NY_death_data.txt",  delim_whitespace=True)
# NY_data_df
New_df = NY_data_df.drop(columns=['Crude', 'Rate'])
New_df
# Out:
#                                                   Notes UCD - ICD Chapter  \
# 0             Certain infectious and parasitic diseases           A00-B99
# 1             Certain infectious and parasitic diseases           A00-B99
# 2             Certain infectious and parasitic diseases           A00-B99
# 3             Certain infectious and parasitic diseases           A00-B99
# 4             Certain infectious and parasitic diseases           A00-B99
# 5             Certain infectious and parasitic diseases           A00-B99
# 6             Certain infectious and parasitic diseases           A00-B99
# 7             Certain infectious and parasitic diseases           A00-B99
# 8             Certain infectious and parasitic diseases           A00-B99
# 9             Certain infectious and parasitic diseases           A00-B99
# 10            Certain infectious and parasitic diseases           A00-B99
# 11            Certain infectious and parasitic diseases           A00-B99
# ...

# %%
cleanNYDatadf = New_df.dropna(thresh=2)
cleanNYDatadf
# Out:
#                                            Notes UCD - ICD Chapter  \
# 0      Certain infectious and parasitic diseases           A00-B99
# 1      Certain infectious and parasitic diseases           A00-B99
# 2      Certain infectious and parasitic diseases           A00-B99
# 3      Certain infectious and parasitic diseases           A00-B99
# 4      Certain infectious and parasitic diseases           A00-B99
# 5      Certain infectious and parasitic diseases           A00-B99
# 6      Certain infectious and parasitic diseases           A00-B99
# 7      Certain infectious and parasitic diseases           A00-B99
# 8      Certain infectious and parasitic diseases           A00-B99
# 9      Certain infectious and parasitic diseases           A00-B99
# 10     Certain infectious and parasitic diseases           A00-B99
# 11     Certain infectious and parasitic diseases           A00-B99
# 12     Certain infectious and parasitic diseases           A00-B99
# ...

# %%
cleanNYDatadf.to_csv(r'NY_clean_data.csv')

# %%
cleanNYDatadf.to_json(r'NY_clean_data.json',orient='split')
